# %% [markdown]
# 1. Write a Python program to create a class representing a Circle. Include methods to calculate its area and perimeter.

# %%
class Circle:
  def __init__(self,radius):
    self.radius=radius

  def area(self):
    return 3.14*self.radius*self.radius

  def perimeter(self):
    return 2*3.14*self.radius

a=Circle(11)
print(a.area())
print(a.perimeter())
# Out:
# 379.94
# 69.08

# %% [markdown]
# 2. Write a Python program to create a person class. Include attributes like name, country and date of birth. Implement a method to determine the person's age.

# %%
from datetime import date
class Person:


  def __init__(self,name,country,y,m,d):
    self.name=name
    self.country=country
    self.dob=date(y,m,d)
    self.today=date.today()

  def age(self):
    year=self.today.year-self.dob.year-((self.today.month,self.today.day)<(self.dob.month,self.dob.day))
    month=((self.today.month-self.dob.month) if self.today.month > self.dob.month else (self.today.month-self.dob.month+12))-((self.today.day)<(self.dob.day))
    days=(self.today.day-self.dob.day) if self.today.day > self.dob.day else (self.today.day-self.dob.day+30)
    return "{}'s age is {} years {} months {} days".format(self.name,year,month,days)



p1=Person('ram','india',1997,6,27)
print(p1.age())
p2=Person('jai',"india",1967,7,20)
print(p2.age())
# Out:
# ram's age is 28 years 9 months 11 days
# jai's age is 58 years 8 months 18 days

# %% [markdown]
# 3. Write a Python program to create a calculator class. Include methods for basic arithmetic operations.

# %%
class Calculator:
  def __init__(self):

    # self.num1=int(input("Enter first number: "))
    # self.num2=int(input("Enter second number: "))
    self.menu()

  def menu(self):
    operator=input("""Select the operation:
    1. Addition
    2. Subtraction
    3. Multiplication
    4. Division
    5. Modulus
    6. Exit

    """)
    if operator=='1':
      self.addition()
    elif operator=='2':
      self.subtraction()
    elif operator=='3':
      self.multiply()
    elif operator=='4':
      self.division()
    elif operator=='5':
      self.modulus()
    elif operator=='6':
      exit()
    else:
      print('Invalid Input')
      self.menu()

  def user_input(self):
    self.num1=int(input("Enter first number: "))
    self.num2=int(input("Enter second number: "))

  def addition(self):
    self.user_input()
    sum = self.num1 + self.num2
    print("{} + {} = {}".format(self.num1,self.num2,sum))
    self.menu()

  def subtraction(self):
    self.user_input()
    sub= self.num1 - self.num2
    print("{} - {} = {}".format(self.num1,self.num2,sub))
    self.menu()

  def multiply(self):
    self.user_input()
    product=self.num1 * self.num2
    print("{} * {} = {}".format(self.num1,self.num2,product))
    self.menu()

  def division(self):
    self.user_input()
    quotiont=self.num1 / self.num2
    print("{} / {} = {}".format(self.num1,self.num2,quotiont))
    self.menu()

  def modulus(self):
    self.user_input()
    remainder=self.num1 % self.num2
    print("{} * {} = {}".format(self.num1,self.num2,remainder))
    self.menu()



c1=Calculator()
# Out:
# Select the operation:
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Division
#     5. Modulus
#     6. Exit
#
#     5
# Enter first number: 23
# Enter second number: 12
# 23 * 12 = 11
# Select the operation:
#     1. Addition
#     2. Subtraction
#     3. Multiplication
#     4. Division
#     5. Modulus
#     6. Exit
#
#     6

# %% [markdown]
# 4. Write a Python program to create a class that represents a shape. Include methods to calculate its area and perimeter. Implement subclasses for different shapes like circle, triangle, and square.

# %%
from abc import ABC,abstractmethod
import math
class Shape(ABC):
  @abstractmethod
  def area(self):
    pass

  @abstractmethod
  def perimeter(self):
    pass

class Circle(Shape):
  def __init__(self,radius):
    self.radius=radius

  def area(self):
    area=math.pi*self.radius*self.radius
    return area

  def perimeter(self):
    perimeter=2*math.pi*self.radius
    return perimeter

class Square(Shape):
  def __init__(self,side):
    self.side=side

  def area(self):
    area=self.side*self.side
    return area

  def perimeter(self):
    perimeter=4*self.side
    return perimeter

class Triangle(Shape):
  def __init__(self,a,b,c):
    self.a=a
    self.b=b
    self.c=c

  def area(self):
    s=(self.a + self.b + self.c)/2
    area=math.sqrt(s* (s-self.a) * (s-self.b) * (s-self.c))
    return area

  def perimeter(self):
    perimeter=self.a + self.b + self.c
    return perimeter

c1=Circle(5)
s1=Square(5)
t1=Triangle(6,8,10)

print(c1.area(),c1.perimeter())
print(s1.area(),s1.perimeter())
print(t1.area(),t1.perimeter())
# Out:
# 78.53981633974483 31.41592653589793
# 25 20
# 24.0 24

# %% [markdown]
# 5. Write a Python program to create a class representing a binary search tree. Include methods for inserting and searching for elements in the binary tree.

# %% [markdown]
# 6. Write a Python program to create a class representing a stack data structure. Include methods for pushing and popping elements.

# %%
class Stack:
  def __init__(self):
    self.items=[]

  def push(self,val):
    self.items.append(val)
    print("{} is push successfully".format(val))

  def pop(self):
    if len(self.items)==0:
      print("Stack is empty")

    else:
      self.items.pop()

  def display(self):
    print(self.items)

list1=[1,2,3,4]
s1=Stack()
for i in list1:
  s1.push(i)
s1.display()
s1.pop()
s1.pop()
s1.display()
# Out:
# 1 is push successfully
# 2 is push successfully
# 3 is push successfully
# 4 is push successfully
# [1, 2, 3, 4]
# [1, 2]

# %% [markdown]
# 7. Write a Python program to create a class representing a linked list data structure. Include methods for displaying linked list data, inserting and deleting nodes.

# %% [markdown]
# 8. Write a Python program to create a class representing a shopping cart. Include methods for adding and removing items, and calculating the total price.

# %%
class Cart:
  dict1={'a':20,'b':25,'c':30}

  def __init__(self):
    self.list=[]

  def add_items(self,item,q):

    if item in Cart.dict1.keys():
      self.list.append([item,Cart.dict1[item],q])
    else:
      print("item not available")


  def remove_item(self,ri):
    for i in range(len(self.list)):
      if ri==self.list[i][0]:
        self.list.pop(i)

  def display(self):
    print(self.list)

  def price(self):
    price=0
    for i in range(len(self.list)):
      price += self.list[i][1]*self.list[i][2]
    return "toatl price of items in cart is: {}.".format(price)

c1=Cart()
c1.add_items('a',2)
c1.add_items('b',2)
c1.display()
c1.price()
# Out:
# [['a', 20, 2], ['b', 25, 2]]
# 'toatl price of items in cart is: 90.'

# %% [markdown]
# 9. Write a Python program to create a class representing a stack data structure. Include methods for pushing, popping and displaying elements.

# %%
class Stack:
  def __init__(self):
    self.items=[]

  def push(self,val):
    self.items.append(val)
    print("{} is push successfully".format(val))

  def pop(self):
    if len(self.items)==0:
      print("Stack is empty")

    else:
      self.items.pop()

  def display(self):
    print(self.items)

list1=[1,2,3,4]
s1=Stack()
for i in list1:
  s1.push(i)
s1.display()
s1.pop()
s1.pop()
s1.display()
# Out:
# 1 is push successfully
# 2 is push successfully
# 3 is push successfully
# 4 is push successfully
# [1, 2, 3, 4]
# [1, 2]

# %% [markdown]
# 10. Write a Python program to create a class representing a queue data structure. Include methods for enqueueing and dequeueing elements.

# %%
class Queue:
  def __init__(self):
    self.items=[]

  def enqueue(self,val):
    self.items.append(val)
    print("{} is push successfully".format(val))

  def dequeue(self):
    if len(self.items)==0:
      print("Stack is empty")

    else:
      self.items.pop(0)

  def display(self):
    print(self.items)

list1=[1,2,3,4]
q1=Queue()
for i in list1:
  q1.enqueue(i)
q1.display()
q1.dequeue()
q1.dequeue()
q1.display()
# Out:
# 1 is push successfully
# 2 is push successfully
# 3 is push successfully
# 4 is push successfully
# [1, 2, 3, 4]
# [3, 4]

# %% [markdown]
# 11. Write a Python program to create a class representing a bank. Include methods for managing customer accounts and transactions.
# 	Create a Python class called BankAccount which represents a bank account, having as attributes: accountNumber (numeric type), name (name of the account owner as string type), balance.
# 	Create a constructor with parameters: accountNumber, name, balance.
# 	Create a Deposit() method which manages the deposit actions.
# 	Create a Withdrawal() method which manages withdrawals actions.
# 	Create an bankFees() method to apply the bank fees with a percentage of 5% of the balance account.
# 	Create a display() method to display account details. Give the complete code for the BankAccount class.

# %%
class BankAccount:
  def __init__(self,accno,name,balance):
    self.accno=accno
    self.name=name
    self.balance=balance
    self.menu()

  def menu(self):
    user_input=input("""Enter the choice:
    1. Deposit
    2. Withdrawal
    3. Bankfees
    4. Display
    """)

    if user_input=='1':
      self.deposit()
    elif user_input=='2':
      self.withdrawal()
    elif user_input=='3':
      self.bankfees()
    elif user_input=='4':
      self.display()
    else:
      print('Invalid input')

  def deposit(self):
    amt=int(input("Enter the amount to deposit: "))
    self.balance+=amt
    print("Rs {} credited in account. Current balance is {}".format(amt,self.balance))
    self.menu()

  def withdrawal(self):
    amt1=int(input("Enter the amount to withdrawal: "))
    if self.balance>=amt1:
      self.balance-=amt1
      print("Rs {} debited from account. Current balance is {}".format(amt1,self.balance))
    else:
      print("Insufficient balance")
    self.menu()

  def bankfees(self):
    bankfee=0.05*self.balance
    self.balance-=bankfee
    print("Rs {} deducted toward bank fee charges. Current balance is {}".format(bankfee,self.balance))
    self.menu()

  def display(self):
    print("Account number: {}".format(self.accno),"\nName: {}".format(self.name),"\nBalance: {}".format(self.balance))
    self.menu()



b1=BankAccount(1234,'Raj',1000)
# Out:
# Enter the choice:
#     1. Deposit
#     2. Withdrawal
#     3. Bankfees
#     4. Display
#     1
# Enter the amount to deposit: 15000
# Rs 15000 credited in account. Current balance is 16000
# Enter the choice:
#     1. Deposit
#     2. Withdrawal
#     3. Bankfees
#     4. Display
#     2
# Enter the amount to withdrawal: 6000
# Rs 6000 debited from account. Current balance is 10000
# Enter the choice:
#     1. Deposit
#     2. Withdrawal
#     3. Bankfees
#     4. Display
#     3
# Rs 500.0 deducted toward bank fee charges. Current balance is 9500.0
# Enter the choice:
#     1. Deposit
#     2. Withdrawal
#     3. Bankfees
#     4. Display
#     4
# Account number: 1234
# Name: Raj
# Balance: 9500.0
# Enter the choice:
#     1. Deposit
#     2. Withdrawal
#     3. Bankfees
#     4. Display
#     5
# Invalid input

# %% [markdown]
# 12. Build a flashcard using class in python. A flashcard is a card having information on both sides, which can be used as an aid in memoization. Flashcards usually have a question on one side and an answer on the other.
#
# 	Example 1:
#
# 	Approach:
#
# 	Create a class named FlashCard.
# 	Initialize dictionary fruits using init() method. Here you have to define fruit name as key and it's color as value. E.g., {"Banana": "yellow", "Strawberries": "pink"}
# 	Now randomly choose a pair from fruits by using random module and store the key in variable fruit and value in variable color.
# 	Now prompt the user to answer the color of the randomly chosen fruit.
# 	If correct print correct else print wrong.
# 	Output:
#
# 	welcome to fruit quiz
# 	What is the color of Strawberries
# 	pink
# 	Correct answer
# 	Enter 0, if you want to play again: 0
# 	What is the color of watermelon
# 	green
# 	Correct answer
# 	Enter 0, if you want to play again: 1

# %%
import random
class FlashCard:

  def __init__(self):
    self.__fruits={
        'mango':'yellow',
        'grapes':'green',
        'apple':'red',
        'orange':'orange',
        'watermelon':'green',
        'gauava':'green',
        "Banana": "yellow",
        "Strawberries": "pink"
    }

  def quiz(self):

    while True:

      fruit,color=random.choices(list(self.__fruits.items()))[0]
      print("Welcome to fruit quiz!!")
      print("What is the color of {}".format(fruit))
      ans=input()
      if ans.lower()==color:
        print('Correct answer')
      else:
        print('Better luck next time')

      a=int(input("Enter 0 to play again Enter 1 to exit: "))

      if a==1:
        break

f1=FlashCard()
f1.quiz()
# Out:
# Welcome to fruit quiz!!
# What is the color of orange
# 23
# Better luck next time
# Enter 0 to play again Enter 1 to exit: 0
# Welcome to fruit quiz!!
# What is the color of Banana
# yellow
# Correct answer
# Enter 0 to play again Enter 1 to exit: 1

# %% [markdown]
# 13. TechWorld, a technology training center, wants to allocate courses for instructors. An instructor is identified by name, technology skills, experience and average feedback. An instructor is allocated a course, if he/she satisfies the below two conditions:
#
# 	eligibility criteria:
# 	if experience is more than 3 years, average feedback should be 4.5 or more
# 	if experience is 3 years or less, average feedback should be 4 or more
# 	he/she should posses the technology skill for the course
# 	Identify the class name and attributes to represent instructors. Write a Python program to implement the class chosen with its attributes and methods.
#
# 	Note:
#
# 	Consider all instance variables to be private and methods to be public.
# 	An instructor may have multiple technology skills, so consider instance variable, technology_skill to be a list.
# 	check_eligibility(): Return true if eligibility criteria is satisfied by the instructor. Else, return false
# 	allocate_course(technology): Return true if the course which requires the given technology can be allocated to the instructor. Else, return false.
# 	Represent a few objects of the class, initialize instance variables using setter methods, invoke appropriate methods and test your program.

# %%
class Instructor:
  def __init__(self,name,technology,experience,feedback):
    self.__name=name
    self.__technology=technology
    self.__experience=experience
    self.__feedback=feedback

  def check_eligible(self):
    if self.__experience > 3 and self.__feedback >=4.5:
      return True
    elif self.__experience <= 3 and self.__feedback >=4:
      return True
    else:
      return False

  def allocate(self,tech):
    eligible=self.check_eligible()
    if eligible:
      if tech in self.__technology:
        return ("{} has allocated {} course".format(self.__name,tech))
      else:
        return ("Not Allocate")
    else:
      return ("Not Eligible")

i1=Instructor('Shree',['python','sql','ai'],2,4)
i1.allocate('aii')
# Out:
# 'Not Allocate'

# %% [markdown]
# 14. Write a program that uses datetime module within a class. Enter manufacturing date and expiry date of the product. The program must display the years, months and days that are left for expiry.

# %%
from datetime import date
class expiry_duration:
  def __init__(self,my,mm,md,ey,em,ed):
    self.manu_date=date(my,mm,md)
    self.expiry_date=date(ey,em,ed)
    self.today=date.today()

  def duration(self):
    year=self.expiry_date.year-self.today.year-((self.today.month,self.today.day)>(self.expiry_date.month,self.expiry_date.day))
    month=((self.expiry_date.month-self.today.month) if self.today.month < self.expiry_date.month else (self.expiry_date.month-self.today.month+12))-((self.today.day)>(self.expiry_date.day))
    days=(self.expiry_date.day-self.today.day) if self.today.day < self.expiry_date.day else (self.expiry_date.day-self.today.day+30)
    return "Duration left to expire is {} years {} months {} days".format(year,month,days)

p1=expiry_duration(2025,5,23,2027,6,12)
p1.duration()
# Out:
# 'Duration left to expire is 1 years 2 months 4 days'

# %%
from datetime import date,datetime
class expiry_duration:
  def __init__(self,manu_date,exp_date):
    self.manu_date=datetime.strptime(manu_date, "%d/%m/%Y")
    self.expiry_date=datetime.strptime(exp_date, "%d/%m/%Y")
    self.today=date.today()

  def duration(self):
    year=self.expiry_date.year-self.today.year-((self.today.month,self.today.day)>(self.expiry_date.month,self.expiry_date.day))
    month=((self.expiry_date.month-self.today.month) if self.today.month < self.expiry_date.month else (self.expiry_date.month-self.today.month+12))-((self.today.day)>(self.expiry_date.day))
    days=(self.expiry_date.day-self.today.day) if self.today.day < self.expiry_date.day else (self.expiry_date.day-self.today.day+30)
    return "Duration left to expire is {} years {} months {} days".format(year,month,days)

p1=expiry_duration('23/10/2025','24/10/2026')
p1.duration()
# Out:
# 'Duration left to expire is 0 years 6 months 16 days'

# %% [markdown]
# 15. A university wants to automate their admission process. Students are admitted based on the marks scored in the qualifying exam. A student is identified by student id, age and marks in qualifying exam. Data are valid, if:
#
# 	Age is greater than 20
# 	Marks is between 0 and 100 (both inclusive)
# 	A student qualifies for admission, if
#
# 	Age and marks are valid and
# 	Marks is 65 or more
# 	Write a python program to represent the students seeking admission in the university.

# %%
class Admision:
  def __init__(self):
    self.__stud_id= None
    self.__age= None
    self.__marks= None

  #setter method
  def set_details(self,id,age,marks):
    self.__stud_id= id
    self.__age= age
    self.__marks= marks

  #getter method
  def get_details(self):
    return self.__stud_id,self.__age,self.__marks

  def validation(self):
    return (self.__age > 20) and (self.__marks >=0 and self.__marks <=100)

  def qualify(self):
    if self.validation():
      if self.__marks > 65:
        return "Student Qualify for Admission"
      else:
        return "Student Not Qualify for Admission"
    else:
      return "not eligible"

a1=Admision()
a1.set_details(101,21,67)
print(a1.get_details())
print(a1.qualify())
# Out:
# <class 'int'>
# (101, 21, 67)
# Student Qualify for Admission

# %% [markdown]
# 16. Ice-Cream Scoops and Bowl shop
#
# 	Create a class Scoop which has one public property flavor and one private proptery price. Take flavor values during object creation.
#
# 	Create a class Bowl with private prperty scoop_list which will have list of scoopd object.
#
# 	Create a method add_scoops in Bowl class which will add any no of Scoop objects given as parameter and store it in scoops_list.
#
# 	Make getter and setter method for price property.
#
# 	Make a method display to display flavour and price of each Scoop in scoop_list and print total price of the bowl by adding all flavour scoops prices.
#
# 	Make a method sold in both Scoop class and Bowl class to print no of quantity sold.

# %%
class Scoop:
  __count=0
  def __init__(self,flavor):
    self.flavor=flavor
    self.__price=None
    Scoop.__count+=1

  def get_price(self):
    return self.__price

  def set_price(self,price):
    self.__price=price



  def __str__(self):
    return "Flavor - {} Price - {}".format(self.flavor,self.__price)

  @staticmethod
  def sold():
    return Scoop.__count

class Bowl:
  __count=0

  def __init__(self):
    self.__scooplist=[]
    Bowl.__count+=1

  def add_scoop(self,*args):
    for i in args:
      self.__scooplist.append(i)

  def dispaly(self):
    total=0
    for i in self.__scooplist:
      print(i)
      total= total+ i.get_price()

    print('Total price : ',total)

  def sold():
    return Bowl.__count

# %%
s1=Scoop('chocalate')
s1.set_price(120)
s2=Scoop('berry')
s2.set_price(100)
s3=Scoop('vanilla')
s3.set_price(110)

b1=Bowl()
b1.add_scoop(s1,s2)
b1.add_scoop(s3)
b1.dispaly()
print(Scoop.sold())
print(Bowl.sold())
# Out:
# Flavor - vanilla Price - 110
# Total price :  110
# 9
# 3

# %% [markdown]
# 17. Create a Bus child class that inherits from the Vehicle class. The default fare charge of any vehicle is seating capacity * 100. If Vehicle is Bus instance, we need to add an extra 10% on full fare as a maintenance charge. So total fare for bus instance will become the final amount = total fare + 10% of the total fare.
#
# Note: The bus seating capacity is 50. so the final fare amount should be 5500. You need to override the fare() method of a Vehicle class in Bus class.

# %%
class Vehicle:
  def __init__(self,capacity):
    self.capacity=capacity

  def fare(self):
    fare=self.capacity*100
    return (fare)

class Bus(Vehicle):
  def fare(self):
    fare=self.capacity*100*1.1
    return fare

b1=Bus(50)
print(b1.fare())
# Out:
# 5500.0

# %% [markdown]
# 18. Write a Python class Employee with attributes like emp_id, emp_name, emp_salary, and emp_department and methods like calculate_emp_salary, emp_assign_department, and print_employee_details.
#
# 	Sample Employee Data:
# 	"ADAMS", "E7876", 50000, "ACCOUNTING"
# 	"JONES", "E7499", 45000, "RESEARCH"
# 	"MARTIN", "E7900", 50000, "SALES"
# 	"SMITH", "E7698", 55000, "OPERATIONS"
#
# 	Use 'assign_department' method to change the department of an employee.
# 	Use 'print_employee_details' method to print the details of an employee.
# 	Use 'calculate_emp_salary' method takes two arguments: salary and hours_worked, which is the number of hours worked by the employee. If the number of hours worked is more than 50, the method computes overtime and adds it to the salary. Overtime is calculated as following formula:
# 	overtime = hours_worked - 50
# 	Overtime amount = (overtime * (salary / 50))

# %%
class Employee:
  def __init__(self,emp_id,emp_name,emp_salary,emp_dept):
    self.emp_id=emp_id
    self.emp_name=emp_name
    self.emp_salary=emp_salary
    self.emp_dept=emp_dept

  def assign_dept(self,new_dept):
    self.emp_dept=new_dept

  def cal_salary(self,hrs):
    if hrs>50:
      self.emp_salary+=(hrs-50)*self.emp_salary/50
    return self.emp_salary

  def print_details(self):
    print("""
    Employee Id : {}
    Employee Name : {}
    Employee Department : {}
    Employee Salary : {}
    """.format(self.emp_id,self.emp_name,self.emp_dept,self.emp_salary)

    )

# %%
e1=Employee('E7876','Adams',50000,'Accounting')
e1.print_details()
e1.assign_dept('Research')
e1.print_details()
e1.cal_salary(52)
e1.print_details()
# Out:
#     Employee Id : E7876
#     Employee Name : Adams
#     Employee Department : Accounting
#     Employee Salary : 50000
#
#
#     Employee Id : E7876
#     Employee Name : Adams
#     Employee Department : Research
#     Employee Salary : 50000
#
#
#     Employee Id : E7876
#     Employee Name : Adams
#     Employee Department : Research
#     Employee Salary : 52000.0

# %% [markdown]
# 19. Write a Python class Restaurant with attributes like menu_items, book_table, and customer_orders, and methods like add_item_to_menu, book_tables, and customer_order.
#
# 	Perform the following tasks now:
#
# 	Now add items to the menu.
# 	Make table reservations.
# 	Take customer orders.
# 	Print the menu.
# 	Print table reservations.
# 	Print customer orders.
# 	Note: Use dictionaries and lists to store the data.

# %%
class Restaurant:
  def __init__(self,menu_items,tables):
    self.menu_items=menu_items
    self.tables=tables
    self.customer_orders=[]

  def display_menu(self):
    return self.menu_items

  def add_items_menu(self,items):
    self.menu_items.extend(items)
    return self.menu_items

  def book_tables(self):
    booked_table=self.tables.pop()
    return "Table No. {} is booked".format(booked_table)

  def customer_order(self,item):
    # self.customer_orders.extend(item)
    # return self.customer_orders

    if set(item).issubset(set(self.menu_items)):
      self.customer_orders.extend(item)
      print("Order taken sucessfully. Order is {}".format(item))
    else:
      not_ava=list(set(item)-set(self.menu_items))
      print('{} items not available'.format(not_ava))
    return self.customer_orders

r1=Restaurant(['roti','dal','steam rice','panner'],[1,2,3,4,5,6])
r1.display_menu()
r1.add_items_menu(['fried rice','dal tadka'])
r1.display_menu()
r1.customer_order(['as','roti','dal tadka','panner'])
# Out:
# ['as'] items not available
# []

# %% [markdown]
# 20. Write a Python class BankAccount with attributes like account_number, balance, date_of_opening and customer_name, and methods like deposit, withdraw, and check_balance.

# %%
from datetime import datetime
class BankAccount1:
  def __init__(self,acc_no,cust_name,doo,bala):
    self.acc_no=acc_no
    self.cust_name=cust_name
    self.date_of_opening=datetime.strptime(doo, "%d/%m/%Y")
    self.balance=bala

  def deposite(self,amt):
    self.balance+=amt
    return ("{} amount deposited".format(amt))

  def withdrawal(self,amt1):
    if self.balance> amt1:
      self.balance-=amt1
      return ("{} amount withdrawn from account".format(amt1))
    else:
      return ("Inssuficient balance")

  def check_balance(self):
      return ("current balance is {}".format(self.balance))


b1=BankAccount1(101,'Virat','12/10/2023',10000)
b1.date_of_opening
b1.deposite(10000)
b1.check_balance()
b1.withdrawal(5000)
b1.check_balance()
b1.withdrawal(50000)
# Out:
# 'Inssuficient balance'

# %%
#datetime.strptime(date_str, "%d-%m-%Y")

# %% [markdown]
# 21. Write a Python class Inventory with attributes like item_id, item_name, stock_count, and price, and methods like add_item, update_item, and check_item_details.

# %%
class Inventory:

  def __init__(self):
    self.details={}

  def add_item(self,item_id,item_name,stock_count,price):
    if item_id in self.details:
      print("item with {} already exists".format(item_id))
    else:
      self.details[item_id]={
          "item_name":item_name,
          "stock":stock_count,
          "price":price
      }
      print("item added successfully")

  def update_item(self,item_id,item_name=None,stock_count=None,price=None):
    if item_id not in self.details:
      print("item not found")

    else:
      if item_name is not None:
        self.details[item_id]["item_name"] = item_name
      if stock_count is not None:
        self.details[item_id]["stock"] = stock_count
      if price is not None:
        self.details[item_id]["price"] = price

      print('Update successful')

  def check_item(self,item_id):
    if item_id not in self.details:
      print("item not found")

    else:
      print(f"""
      item is: {item_id}
      item name: {self.details[item_id]["item_name"]}
      stock: {self.details[item_id]["stock"]}
      price: {self.details[item_id]["price"]}
          """)

# %%
i1=Inventory()
i1.add_item(1, "Laptop", 10, 50000)
i1.add_item(2, "Mouse", 50, 500)
print(i1.details)
i1.update_item(1, stock_count=8, price=48000)
print(i1.details)
i1.check_item(2)
# Out:
# item added successfully
# item added successfully
# {1: {'item_name': 'Laptop', 'stock': 10, 'price': 50000}, 2: {'item_name': 'Mouse', 'stock': 50, 'price': 500}}
# Update successful
# {1: {'item_name': 'Laptop', 'stock': 8, 'price': 48000}, 2: {'item_name': 'Mouse', 'stock': 50, 'price': 500}}
#
#       item is: 2
#       item name: Mouse
#       stock: 50
#       price: 500
